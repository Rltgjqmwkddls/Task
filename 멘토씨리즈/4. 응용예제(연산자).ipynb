# %%
# 임의의 두 자리 정수를 입력받아서 십의 자리와 일의 자리로 분리하여 출력
num = input('10~99 사이의 정수를 입력하세요: ')

a = num[0]
b = num[1]

print('십의 자리: {}'.format(a))
print('일의 자리: {}'.format(b))
# Out:
# 10~99 사이의 정수를 입력하세요: 45.5
# 십의 자리: 4
# 일의 자리: 5

# %%
num = int(input('10~99 사이의 정수를 입력하세요: '))

a = num // 10
b = num % 10

print('십의 자리: {}'.format(a))
print('일의 자리: {}'.format(b))
# Out:
# 10~99 사이의 정수를 입력하세요: 45
# 십의 자리: 4
# 일의 자리: 5

# %%
# 1분은 60초이고, 1시간은 60분입니다. 따라서 1시간은 3600초입니다. 임의의 초를 입력받아 해당 초를 시, 분, 초로 변환하여 출력
num = int(input('초를 입력하세요: '))

h = num // 3600 # 시 계산
S = num % 3600 # 남은 초 계산
m = S // 60 # 분 계산
s = S % 60 # 초 계산
print(f'변환결과는 {h}시간 {m}분 {s}초 입니다.')
# Out:
# 초를 입력하세요: 3690
# 변환결과는 1시간 1분 30초 입니다.

# %%
# 네 자리 정수로 구성된 사원번호를 기준으로 근무 시간을 결정하고자 함. 사원번호의 끝자리 숫자가 5이상인 이면 '오전', 아니면 '오후'를 출력
num = int(input('4자리 사원번호를 입력하세요: '))
result = '오전' if num % 10 >= 5  else '오후'
print(f'사원의 근무 시간은: {result}입니다.')
# Out:
# 4자리 사원번호를 입력하세요: 1254
# 사원의 근무 시간은: 오후입니다.

# %%
# 1박스에 라면이 20개씩 들어감. 라면의 개수를 입력받아 라면을 담기 위해서 필요한 박스의 개수를 구하기
food = int(input('라면의 개수를 입력하세요: '))

box = (food // 20) + (0 if food % 20 == 0 else 1)

print(f'{food}개 라면을 담으려면 {box}박스가 필요합니다.')
# Out:
# 라면의 개수를 입력하세요: 50
# 50개 라면을 담으려면 3박스가 필요합니다.

# %%
# 국어, 영어, 수학 점수를 각각 입력받아서 평균을 구하고, 평균이 80점 이상이면, '합격', 아니면 '불합격'을 출력
kor = int(input('국어 점수를 입력하세요: '))
eng = int(input('영어 점수를 입력하세요: '))
math = int(input('수학 점수를 입력하세요: '))
score = kor + eng + math
avg = score // 3
result = '합격' if avg >= 80 else '불합격'
print(f'평균은{avg}점이고, 결과는 {result}입니다.')
# Out:
# 국어 점수를 입력하세요: 50
# 영어 점수를 입력하세요: 100
# 수학 점수를 입력하세요: 70
# 평균은73점이고, 결과는 불합격입니다.
