# %%
# 우리나라의 전화번호는 '지역번호-국번-가입자개별번호' 형식
# 어떤 형식의 전화번호를 입력하더라도 '국번'을 추출
num = input('전화번호를 입력하세요: ')
n = num.split('-')
n[1]
# Out:
# 전화번호를 입력하세요: 010-8287-1463
# '8287'

# %%
# 숫자3자리-숫자2자리-숫자5자리 형식의 사업자등록번호를 입력받아서 형식이 맞는지 점검하는 프로그램
num = input('사업자등록번호를 입력하세요: ')

n = num.split('-')
if len(n[0]) == 3 and n[0].isdecimal() \
and len(n[1]) == 2 and n[1].isdecimal() \
and len(n[2]) == 5 and n[2].isdecimal():
  print('올바른 형식입니다.')
else:
  print('올바른 형식이 아닙니다.')
# Out:
# 사업자등록번호를 입력하세요: 123-45-67890
# 올바른 형식입니다.

# %%
# 우리 학교 성적 관리 프로그램은 다음과 같아("김철수",85)
# 각각 name과 score 변수에 저장
school = input('이름과 성적을 입력하세요: ')
s = school.split(',')
name = s[0]
score = int(s[1])
print(f'이름은{name}이고, 점수는{score}점 입니다.')
# Out:
# 이름과 성적을 입력하세요: 김철수,85
# 이름은김철수이고, 점수는85점 입니다.
