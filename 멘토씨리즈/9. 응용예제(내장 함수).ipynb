# %%
# 무지개의 일곱 색깔을 저장하는 rainbow 리스트를 생성
rainbow = ['red', 'orange', 'yellow', 'green', 'blue', 'navy', 'purple']
for cnt ,i in enumerate(rainbow):
  print(f'무지개의{cnt+1}번째 색은 {i}입니다.')
# Out:
# 무지개의1번째 색은 red입니다.
# 무지개의2번째 색은 orange입니다.
# 무지개의3번째 색은 yellow입니다.
# 무지개의4번째 색은 green입니다.
# 무지개의5번째 색은 blue입니다.
# 무지개의6번째 색은 navy입니다.
# 무지개의7번째 색은 purple입니다.

# %%
# 어떤 학생의 점수를 입력받아 평균 점수, 최고 점수, 최저 점수를 구하는 성적 계산 프로그램 구현
exam = []
while True:
  score = int(input('점수 입력: '))
  if score < 0:
    break
  exam.append(score)
print(exam)
print(f'평균: {sum(exam) // len(exam)}')
print(f'최대: {max(exam)}')
print(f'최소: {min(exam)}')
# Out:
# 점수 입력: 100
# 점수 입력: 50
# 점수 입력: 60
# 점수 입력: 30
# 점수 입력: 20
# 점수 입력: 10
# 점수 입력: 90
# 점수 입력: 80
# 점수 입력: 70
# 점수 입력: -1
# [100, 50, 60, 30, 20, 10, 90, 80, 70]
# 평균: 56
# 최대: 100
# 최소: 10
