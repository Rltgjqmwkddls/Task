# %%
import requests
from bs4 import BeautifulSoup

# %%
def genie(num):
    header = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36'}
    site = f'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20240520&hh=12&rtm=Y&pg={num}'
    request = requests.get(site, headers=header)
    soup = BeautifulSoup(request.text, 'html.parser')
    titles = soup.findAll('a', {'class':'title ellipsis'})
    artists = soup.findAll('a', {'class':'artist ellipsis'})
    data = []
    for title, artist in zip(titles, artists):
        title_text = title.text.strip()
        artist_text = artist.text.strip()
        data.append({'title': title_text, 'artist': artist_text})

    return data

# %%
all_data = []

# %%
for num in range(1, 5):  # 1페이지부터 4페이지까지 순회
    page_data = genie(num)
    all_data.extend(page_data)

# %%
# 1위부터 200위까지 출력
for rank, entry in enumerate(all_data, start=1):
    print(f"{rank}위: {entry['title']} - {entry['artist']}")
# Out:
# 1위: HAPPY - DAY6 (데이식스)
# 2위: Welcome to the Show - DAY6 (데이식스)
# 3위: Supernova - aespa
# 4위: 한 페이지가 될 수 있게 - DAY6 (데이식스)
# 5위: 클락션 (Klaxon) - (여자)아이들
# 6위: 예뻤어 - DAY6 (데이식스)
# 7위: How Sweet - DAY6 (데이식스)
# 8위: 고민중독 - aespa
# 9위: Small girl (Feat. 도경수 (D.O.)) - DAY6 (데이식스)
# 10위: 녹아내려요 - (여자)아이들
# 11위: 소나기 - DAY6 (데이식스)
# 12위: 나는 아픈 건 딱 질색이니까 - NewJeans
# 13위: Supernatural - QWER
# 14위: 첫 만남은 계획대로 되지 않아 - 이영지
# 15위: 해야 (HEYA) - DAY6 (데이식스)
# 16위: 천상연 - 이클립스 (ECLIPSE)
# 17위: 슬픈 초대장 - (여자)아이들
# 18위: Sticky - NewJeans
# 19위: 에피소드 - TWS (투어스)
# 20위: Magnetic - IVE (아이브)
# 21위: SPOT! (Feat. JENNIE) - 이창섭
# 22위: 비의 랩소디 - 순순희 (지환)
# 23위: Love wins all - KISS OF LIFE
# 24위: Armageddon - 이무진
# 25위: 사랑은 늘 도망가 - 아일릿 (ILLIT)
# 26위: Supersonic - 지코 (ZICO)
# 27위: 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection)) - 임재현
# 28위: Bubble Gum - 아이유 (IU)
# 29위: Cruel Summer - aespa
# 30위: 헤어지자 말해요 - 임영웅
# 31위: To. X - 프로미스나인
# 32위: 이제 나만 믿어요 - 너드커넥션 (Nerd Connection)
# 33위: 우리들의 블루스 - NewJeans
# 34위: I AM - Taylor Swift
# 35위: 다정히 내 이름을 부르면 - 박재정
# 36위: 밤양갱 - 태연 (TAEYEON)
# 37위: Ditto - 임영웅
# 38위: 사건의 지평선 - 임영웅
# 39위: Hype Boy - IVE (아이브)
# 40위: Congratulations - 경서예지 & 전건호
# 41위: I Don't Think That I Like Her - 비비 (BIBI)
# 42위: 미안해 미워해 사랑해 - NewJeans
# 43위: Love me or Leave me - 윤하 (YOUNHA)
# 44위: 다시 만날 수 있을까 - NewJeans
# 45위: 모래 알갱이 - DAY6 (데이식스)
# 46위: ETA - Charlie Puth
# 47위: 심 (心) - Crush
# 48위: 무지개 - DAY6 (데이식스)
# 49위: 청혼하지 않을 이유를 못 찾았어 - 임영웅
# 50위: 사랑인가 봐 - 임영웅
# 51위: 퀸카 (Queencard) - DAY6 (데이식스)
# 52위: 너의 모든 순간 - DAY6 (데이식스)
# 53위: Home - aespa
# 54위: When I Get Old - DAY6 (데이식스)
# 55위: 온기 - (여자)아이들
# 56위: Dangerously - (여자)아이들
# 57위: 내가 S면 넌 나의 N이 되어줘 - 성시경
# 58위: Drama - 임영웅
# 59위: 주저하는 연인들을 위해 - Christopher & 청하
# 60위: 별별별 (See that?) - 임영웅
# 61위: Attention - Charlie Puth
# 62위: 위태로울걸 - TWS (투어스)
# 63위: MEOW - aespa
# 64위: London Boy - 잔나비
# 65위: Super Shy - NMIXX
# 66위: 사막에서 꽃을 피우듯 - NewJeans
# 67위: After LIKE - 오반 (OVAN)
# 68위: 인사 - MEOVV (미야오)
# 69위: Love Lee - 임영웅
# 70위: Stay - NewJeans
# 71위: Polaroid - 우디 (Woody)
# 72위: Do or Die - IVE (아이브)
# 73위: LOVE DIVE - 범진
# 74위: 오래된 노래 - AKMU (악뮤)
# 75위: Spicy - The Kid LAROI & Justin Bieber
# 76위: SHEESH - 임영웅
# 77위: 후라이의 꿈 - 임영웅
# 78위: 보금자리 - IVE (아이브)
# 79위: 인생찬가 - 허각 & 임한별 & 이무진 & 이진성 & 김희재 & #안녕
# 80위: 물론 - aespa
# 81위: 연애편지 - BABYMONSTER
# 82위: CRAZY - AKMU (악뮤)
# 83위: 2002 - 임영웅
# 84위: Seven (Feat. Latto) (Clean Ver.) - 임영웅
# 85위: 그녀가 웃었다 - 허각
# 86위: 그대가 내 안에 박혔다 (그내박) - 임영웅
# 87위: OMG - LE SSERAFIM (르세라핌)
# 88위: 아로하 - Anne-Marie
# 89위: 사랑하지 않아서 그랬어 - 정국
# 90위: 면도 - DAY6 (데이식스)
# 91위: 그랬나봐 - 순순희 (기태)
# 92위: 모든 날, 모든 순간 (Every day, Every Moment) - NewJeans
# 93위: 잘 지내자, 우리 (여름날 우리 X 로이킴) - 조정석
# 94위: Off My Face - 임한별
# 95위: 숲 - 조장혁
# 96위: 플러팅 - 유회승 (엔플라잉)
# 97위: 건물 사이에 피어난 장미 - 폴킴
# 98위: Perfect Night - 로이킴
# 99위: Every Second - Justin Bieber
# 100위: 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지 - 최유리
# 101위: Kitsch - DAY6 (데이식스)
# 102위: Discord - DAY6 (데이식스)
# 103위: The Drum - aespa
# 104위: Loving You Girl (Feat. Hkeem) - DAY6 (데이식스)
# 105위: MANIAC - (여자)아이들
# 106위: 참 다행이야 - IVE (아이브)
# 107위: 희재 - QWER
# 108위: That's Hilarious - Alan Walker
# 109위: EASY - Peder Elias
# 110위: Shape Of You - VIVIZ (비비지)
# 111위: 꿈 - Spapa
# 112위: You & Me - 성시경
# 113위: Boom Boom Bass - Charlie Puth
# 114위: 신호등 - LE SSERAFIM (르세라핌)
# 115위: 해요 (2022) - Ed Sheeran
# 116위: 취중고백 - 태연 (TAEYEON)
# 117위: 홀씨 - 제니 (JENNIE)
# 118위: 네가 내 마음에 자리 잡았다 (Into You) - RIIZE
# 119위: Memories - 이무진
# 120위: 그라데이션 - #안녕
# 121위: 혹시 세상에 혼자 남겨진 것 같다면 - 김민석
# 122위: Accendio - 아이유 (IU)
# 123위: NA - 엔플라잉 (N.Flying)
# 124위: 파이팅 해야지 (Feat. 이영지) - Maroon 5
# 125위: Baddie - 10CM
# 126위: SOS - 우디 (Woody)
# 127위: 나의 X에게 - IVE (아이브)
# 128위: TOMBOY - 화사 (HWASA)
# 129위: Beautiful Things - 부석순 (SEVENTEEN)
# 130위: 오래된 노래 - IVE (아이브)
# 131위: Live My Life - FIFTY FIFTY
# 132위: 내가 그댈 - 경서
# 133위: Smoke (Prod. by Dynamicduo & Padi) - (여자)아이들
# 134위: I'm Not The Only One - Benson Boone
# 135위: 봄여름가을겨울 (Still Life) - Standing Egg (스탠딩 에그)
# 136위: 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야 - aespa
# 137위: 어른 - 하동균
# 138위: Girls Never Die - 다이나믹 듀오 & 이영지
# 139위: Summer (Feat. BE'O (비오)) - Sam Smith
# 140위: Bad Habits - BIGBANG (빅뱅)
# 141위: 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온) - 장범준
# 142위: 사랑..그게 뭔데 - Sondia
# 143위: Dynamite - tripleS (트리플에스)
# 144위: 영원 - Paul Blanco
# 145위: Run Run - Ed Sheeran
# 146위: Love 119 - 마크툽 (Maktub)
# 147위: 내 손을 잡아 - 지아
# 148위: 그때 그 순간 그대로 (그그그) - 방탄소년단
# 149위: 태양물고기 - DK (디셈버)
# 150위: 잠깐 시간 될까 - 이클립스 (ECLIPSE)
# 151위: 첫눈처럼 너에게 가겠다 - DAY6 (데이식스)
# 152위: 손오공 - DAY6 (데이식스)
# 153위: 벌써 일년 - aespa
# 154위: 내가 아니라도 - DAY6 (데이식스)
# 155위: 밤하늘의 별을 (2020) - (여자)아이들
# 156위: 이브, 프시케 그리고 푸른 수염의 아내 - 에일리 (Ailee)
# 157위: Steal The Show - 세븐틴 (SEVENTEEN)
# 158위: 다시 사랑한다면 (니글니글 버터플라이) - 브라운 아이즈
# 159위: 아직 거기 살아 - 주호
# 160위: Stronger (What Doesn't Kill You) - 경서
# 161위: Underwater - LE SSERAFIM (르세라핌)
# 162위: BETELGEUSE - Lauv
# 163위: Monologue - 김필
# 164위: These Tears - DAY6 (데이식스)
# 165위: Way Back Home - Kelly Clarkson
# 166위: 괴물 - 권은비
# 167위: Balloon in Love - Yuuri
# 168위: Touch - 테이 (Tei)
# 169위: Bad - Andy Grammer
# 170위: 거리에서 (Feat. ASH ISLAND) - 숀 (SHAUN)
# 171위: 사랑이 죄야? (Feat. 10CM & B.I) - DAY6 (데이식스)
# 172위: MAESTRO - 선미
# 173위: Shut Down - KATSEYE
# 174위: 도와줘요 Rock&Roll - Christopher
# 175위: Chk Chk Boom - 릴러말즈 (Leellamarz)
# 176위: 시작 - KIXO (키조)
# 177위: Blueming - 세븐틴 (SEVENTEEN)
# 178위: 있잖아 - BLACKPINK
# 179위: 오르트구름 - DAY6 (데이식스)
# 180위: OHAYO MY NIGHT - Stray Kids (스트레이 키즈)
# 181위: 봄날 - 가호 (Gaho)
# 182위: Get A Guitar - 아이유 (IU)
# 183위: At My Worst - 폴킴
# 184위: ELEVEN - 윤하 (YOUNHA)
# 185위: Cosmic - 디핵 (D-Hack) & PATEKO
# 186위: Fast Forward - 방탄소년단
# 187위: Blue Moon - RIIZE
# 188위: 어땠을까 (Feat. 박정현) - Pink Sweat$
# 189위: 나에게 그대만이 - IVE (아이브)
# 190위: Nice Guy - Red Velvet (레드벨벳)
# 191위: 망겜 - 전소미
# 192위: 사랑앓이 - 엔플라잉 (N.Flying)
# 193위: Celebrity - 싸이 (Psy)
# 194위: UNFORGIVEN (Feat. Nile Rodgers) - 탑현
# 195위: 고민중독 (Ballad Ver.) - BOYNEXTDOOR
# 196위: 봄눈 - DAY6 (데이식스)
# 197위: Next Level - FTISLAND (FT아일랜드)
# 198위: 좋은 밤 좋은 꿈 - 아이유 (IU)
# 199위: 이제는 어떻게 사랑을 하나요 - LE SSERAFIM (르세라핌)
# 200위: Smart - 허용별 (허각 & 신용재 & 임한별)
